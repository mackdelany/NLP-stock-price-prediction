# %%
import pandas as pd

# %%
raw = pd.read_csv('../data/train/RedditNews_train.csv', index_col=0)
raw.loc['2008-08-08', :].head()
# Out:
#                                                          News
# Date
# 2008-08-08  b'Georgian troops retreat from S. Osettain cap...
# 2008-08-08  b"The 'enemy combatent' trials are nothing but...
# 2008-08-08                                                NaN
# 2008-08-08  b'150 Russian tanks have entered South Ossetia...
# 2008-08-08  b'Did the U.S. Prep Georgia for War with Russia?'

# %%
len(raw.iloc[0, :].values[0])
# Out:
# 175

# %%
raw_comb = pd.read_csv('../data/train/Combined_News_DJIA_train.csv', index_col=0)
raw_comb.head()
# Out:
#             Label                                               Top1  \
# Date
# 2008-08-08    0.0  b"Georgia 'downs two Russian warplanes' as cou...
# 2008-08-11    1.0  b'Why wont America and Nato help us? If they w...
# 2008-08-12    0.0  b'Remember that adorable 9-year-old who sang a...
# 2008-08-13    0.0  b' U.S. refuses Israel weapons to attack Iran:...
# 2008-08-14    1.0  b'All the experts admit that we should legalis...
#
#                                                          Top2  \
# Date
# 2008-08-08                                                NaN
# 2008-08-11        b'Bush puts foot down on Georgian conflict'
# 2008-08-12                 b"Russia 'ends Georgia operation'"
# 2008-08-13  b"When the president ordered to attack Tskhinv...
# 2008-08-14  b'War in South Osetia - 89 pictures made by a ...
#
#                                                          Top3  \
# Date
# 2008-08-08  b'Russia Today: Columns of troops roll into So...
# ...

# %%
len(raw_comb.iloc[0, 4])
# Out:
# 139

# %%
raw_numb = pd.read_csv('../data/train/DJIA_table_train.csv', index_col=0)

# %%
raw_numb.head()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2008-08-08  11432.089844           NaN  11388.040039  11734.320312
# 2008-08-11  11729.669922  11867.110352  11675.530273  11782.349609
# 2008-08-12  11781.700195  11782.349609  11601.519531  11642.469727
# 2008-08-13  11632.809570  11633.780273  11453.339844  11532.959961
# 2008-08-14  11532.070312  11718.280273  11450.889648  11615.929688
#
#                  Volume     Adj Close  label
# Date
# 2008-08-08  212830000.0  11734.320312    0.0
# 2008-08-11          NaN  11782.349609    0.0
# 2008-08-12  173590000.0  11642.469727    1.0
# 2008-08-13  182550000.0  11532.959961    1.0
# 2008-08-14  159790000.0  11615.929688    NaN
